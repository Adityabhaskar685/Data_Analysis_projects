# %% [markdown]
# # Airplane Crashes and Fatalities

# %%
# import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# This dataset showcases Boeing 707 accidents that have occurred since 1948. The data includes information on the date, time, location, operator, flight number, route, type of aircraft, registration number, cn/In number of persons on board, fatalities, ground fatalities, and a summary of the accident

# %%
df = pd.read_csv("Airplane_Crashes_and_Fatalities_Since_1908.csv")

# %%
df
# Out:
#       index        Date   Time  \
# 0         0  09/17/1908  17:18
# 1         1  07/12/1912  06:30
# 2         2  08/06/1913    NaN
# 3         3  09/09/1913  18:30
# 4         4  10/17/1913  10:30
# ...     ...         ...    ...
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
# columns name
df.columns
# Out:
# Index(['index', 'Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route',
#        'Type', 'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground',
#        'Summary'],
#       dtype='object')

# %%
# finding na in each columns
df.isna().sum()
# Out:
# index              0
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
df.describe()
# Out:
#             index       Aboard   Fatalities       Ground
# count  5268.00000  5246.000000  5256.000000  5246.000000
# mean   2633.50000    27.554518    20.068303     1.608845
# std    1520.88494    43.076711    33.199952    53.987827
# min       0.00000     0.000000     0.000000     0.000000
# 25%    1316.75000     5.000000     3.000000     0.000000
# 50%    2633.50000    13.000000     9.000000     0.000000
# 75%    3950.25000    30.000000    23.000000     0.000000
# max    5267.00000   644.000000   583.000000  2750.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of       index        Date   Time  \
# 0         0  09/17/1908  17:18
# 1         1  07/12/1912  06:30
# 2         2  08/06/1913    NaN
# 3         3  09/09/1913  18:30
# 4         4  10/17/1913  10:30
# ...     ...         ...    ...
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# ...

# %% [markdown]
# now we intended to find the operators having the maximum amount fo crashes

# %% [markdown]
# # Top Operators Accounting For Craches

# %%
operator_count = df.groupby(["Operator"]).count()["index"]
operator_count = pd.DataFrame(operator_count).dropna(axis="rows")
operator_count = operator_count.rename(columns={'index':'count'})
operator_count = operator_count.sort_values("count",ascending=False)
operator_count
# Out:
#                            count
# Operator
# Aeroflot                     179
# Military - U.S. Air Force    176
# Air France                    70
# Deutsche Lufthansa            65
# United Air Lines              44
# ...                          ...
# Everest Air                    1
# Europe Aero Service EAS        1
# Eurojet Italila                1
# Euroair                        1
# de Havilland Aircraft          1
#
# [2476 rows x 1 columns]

# %%
# creating a bar chart
op_count_x = np.array(operator_count.index)
op_count_y = np.array(operator_count["count"])

plt.barh(op_count_x[:20],op_count_y[:20])
plt.xlabel("Crahes")
plt.ylabel("Top Operators")
# Out:
# Text(0, 0.5, 'Top Operators')

# %% [markdown]
# # Fatalities By Operators

# %%
op_fatalities = pd.DataFrame(df.groupby(["Operator"]).sum()["Fatalities"])
op_fatalities = op_fatalities.sort_values("Fatalities",ascending = False)
op_fatalities_x = op_fatalities.index
op_fatalities_y = op_fatalities["Fatalities"]

plt.barh(op_fatalities_x[:20], op_fatalities_y[:20])
plt.xlabel("Fatalities")
# Out:
# Text(0.5, 0, 'Fatalities')

# %% [markdown]
# # Crahes By Route

# %%
route_count = df.groupby(["Route"]).count().sort_values("index",ascending=False)
rc_x = np.array(route_count.index)
rc_y = np.array(route_count['index'])
plt.barh(rc_x[:20],rc_y[:20])
plt.xlabel("Crashes")
plt.show()

# %% [markdown]
# # Fatalities By Route

# %%
route_fatalities = df.groupby(["Route"]).sum().drop(['index','Ground'],axis='columns')
route_fatalities = route_fatalities.sort_values("Fatalities",ascending=False)
route_fatalities[:20].plot(kind="barh")
plt.xlabel("Passengers")
plt.show()

# %% [markdown]
# # Year Wise Crashes

# %%
y = np.array(df["Date"])
for i in range(len(y)):
    y[i]=int(y[i][6:])
    
sns.histplot(y,color="green",kde = True, cbar_ax=True)
plt.xlabel("Year")
df.insert(loc = 1, column = "Year", value=y)

# %% [markdown]
# # Fatalities By Year

# %%
df.groupby(["Year"]).sum()[["Fatalities","Aboard"]].plot()
plt.show()

# %% [markdown]
# # Crashes By Country/Region

# %%
# country wise analysis
def lastWord(string):
    lis = list(str(string).split(" "))
    lenght = len(lis)
    return lis[lenght-1]
locations = np.array(df["Location"])
countries = []
for i in locations:
    countries.append(lastWord(i))
countries = pd.DataFrame({"Region":countries, "count":np.ones(len(countries))})

# %%
countries_df = countries.groupby("Region").count().sort_values("count",ascending = False)
sns.barplot(x=countries_df["count"][:20], y = countries_df.index[:20])
plt.show()

# %% [markdown]
# # Crashes By Type Of Aircraft Involved

# %%
type_count = df.groupby(["Type"]).count().sort_values("index",ascending=False)
tc_x = type_count.index
tc_y = type_count['index']
plt.barh(tc_x[:20],tc_y[:20])
plt.ylabel("Type Of Aircraft")
plt.xlabel("Craches")
plt.show()

# %% [markdown]
# # Crashes by Time of the Day
# Not very Conclusive

# %%
# note there are plenty of missing entries in the time features of the dataset
# supposedly because of teh intermediate nature of accidents mid-air

time_df = pd.DataFrame(df.groupby(["Time"]).count().sort_values("index",ascending=False)
                       ["index"])
times = np.array(time_df.index)
crash_times = []
for i in range(len(times)):
    if (times[0] == "c"):
        times[i] = times[i][3:5]
    else:
        times[i] = times[i][:2]
        crash_times.append(times[i][:2])

# %%
times = pd.DataFrame({"Hour":crash_times, "count":np.ones(len(crash_times))})
total_by_hour = times.groupby("Hour").count().sort_values("count",ascending=False)
plt.barh(total_by_hour[:20].index,total_by_hour[:20]["count"])
plt.ylabel("Hour")
plt.xlabel("Crashes")
plt.show()

# %%
time_df = pd.DataFrame(df.groupby(["Time"]).count().sort_values("index",ascending=False)
                       ["index"])
time_df.rename({"index":"Count"},axis="columns",inplace=True)
time_df[:200].plot()
plt.ylabel("Crashes")
plt.show()
